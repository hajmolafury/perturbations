# %%
import matplotlib.pylab as plt
import numpy as np
import csv

lr_dict={}

with open('test_acc.csv', 'r') as csvFile:
    reader = csv.reader(csvFile)
    for row in reader:
        if(len(row)<100 and len(row)>5):
            network=row
        elif(len(row)>100 and network[1]=='3'):
            for ii in range(len(row)):
                row[ii]=float(row[ii])
            print(network)
            lr_dict[network[5]]=row
            
csvFile.close()
# Out:
# ['depth', '3', 'width', '300', 'learning rate', '0.005', 'n_epochs', '100000']
# ['depth', '3', 'width', '300', 'learning rate', '0.05', 'n_epochs', '100000']
# ['depth', '3', 'width', '300', 'learning rate', '0.001', 'n_epochs', '150000']
# ['depth', '3', 'width', '300', 'learning rate', '0.003', 'n_epochs', '100000']
# ['depth', '3', 'width', '300', 'learning rate', '0.03', 'n_epochs', '100000']
# ['depth', '3', 'width', '300', 'learning rate', '0.01', 'n_epochs', '100000']

# %%
for key, value in lr_dict.items():
    if(key=='0.05')
        test_acc=value
# Out:
# 0.05
# 0.003
# 0.03
# 0.005
# 0.001
# 0.01

# %%
epochs=np.arange(1,100000,5)

fig, ax1 = plt.subplots(figsize=(8, 5.5))
colors = ['tab:blue', 'm', 'tab:red', 'Green','k','w','y']

ax1.set_xlabel('EPOCHS')
ax1.set_ylabel('ACC')
# for i in range(len(test_acc)):
#     if(i==0 or i==1 or i==2):
#         continue
#     ax1.plot(epochs[20:], train_acc[i][20:], color=colors[i], linestyle='--', marker='.')
clr=0
legend=[]
# for key, value in lr_dict.items():    
#     if(len(value)>20000):
#         continue
#     ax1.plot(epochs, value[4000:], color=colors[clr])
#     clr+=1
#     legend.append(key)

ax1.plot(epochs[1000:], value[1000:], color=colors[0])

plt.gca().legend(legend, loc='lower right')
ax1.set_facecolor("#ffffb3")
    
plt.grid(True, color="#93a1a1", alpha=0.3)
# plt.savefig('test_acc.jpg', dpi=500)

# %%
epochs=np.arange(1,1500,5)

fig, ax1 = plt.subplots(figsize=(8, 5.5))
colors = ['tab:blue', 'm', 'tab:red', 'Green']

ax1.set_xlabel('EPOCHS')
ax1.set_ylabel('NORM')
for i in range(len(test_acc)):
#     if(i==0 or i==1 or i==2):
#         continue
#     ax1.plot(epochs, nonlin_test_acc[i], color=colors[i], linestyle='--', marker='.')
    ax1.plot(epochs[1:], norm_w1[i][1:], color=colors[i])

# plt.gca().legend(('100 nodes','300 nodes', '1000 nodes', '3000 nodes'), loc='lower right')
ax1.set_facecolor("#ffffb3")

plt.grid(True, color="#93a1a1", alpha=0.3)
plt.savefig('test_acc.svg', dpi=500)
